# %% [markdown]
# <a href="https://colab.research.google.com/github/impk415/BoilerCodes/blob/main/epoch_task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import geopandas as gpd
from shapely.geometry import Point

# %%
map_data = gpd.read_file("India_State_Boundary.shp")

# %%
df = pd.read_csv("clustering_data.csv", low_memory= False)

# %%
df.set_index('StateName', inplace = True)

# %%
home_df = df.loc['MAHARASHTRA']

# %%
home_df
# Out:
#                      CircleName         RegionName         DivisionName  \
# StateName
# MAHARASHTRA  Maharashtra Circle      Nagpur Region   Amaravati Division
# MAHARASHTRA  Maharashtra Circle      Nagpur Region  Chandrapur Division
# MAHARASHTRA  Maharashtra Circle      Nagpur Region  Chandrapur Division
# MAHARASHTRA  Maharashtra Circle      Nagpur Region  Chandrapur Division
# MAHARASHTRA  Maharashtra Circle  Aurangabad Region   Osmanabad Division
# ...                         ...                ...                  ...
# MAHARASHTRA  Maharashtra Circle      Nagpur Region  Chandrapur Division
# MAHARASHTRA  Maharashtra Circle      Nagpur Region  Chandrapur Division
# MAHARASHTRA  Maharashtra Circle      Nagpur Region  Chandrapur Division
# MAHARASHTRA  Maharashtra Circle      Nagpur Region  Chandrapur Division
# MAHARASHTRA  Maharashtra Circle  Goa-Panaji Region    Kolhapur Division
#
#                             OfficeName  Pincode OfficeType      Delivery  \
# StateName
# MAHARASHTRA               Bhatkuli S.O   444602         PO  Non Delivery
# MAHARASHTRA                  Subai B.O   442905         BO      Delivery
# MAHARASHTRA             Tembhuwahi B.O   442905         BO      Delivery
# MAHARASHTRA              Vihirgaon B.O   442905         BO      Delivery
# MAHARASHTRA               Nilegaon B.O   413603         BO      Delivery
# ...                                ...      ...        ...           ...
# MAHARASHTRA        Ghugus Colliery S.O   442505         PO      Delivery
# MAHARASHTRA              Gondpipri S.O   442702         PO      Delivery
# MAHARASHTRA               Kurkheda S.O   441209         PO      Delivery
# MAHARASHTRA                Nagbhid S.O   441205         PO      Delivery
# MAHARASHTRA  Ganeshwadi S.O (Kolhapur)   416105         PO      Delivery
#
#                District    Latitude   Longitude
# StateName
# MAHARASHTRA    AMRAVATI      20.907     77.6026
# MAHARASHTRA  CHANDRAPUR  19.5733438  79.4422593
# MAHARASHTRA  CHANDRAPUR  19.6924335  79.3571161
# MAHARASHTRA  CHANDRAPUR  19.7268087   79.453512
# MAHARASHTRA   OSMANABAD   18.010041  76.0710641
# ...                 ...         ...         ...
# MAHARASHTRA  CHANDRAPUR  19.9405833    79.12025
# MAHARASHTRA  CHANDRAPUR  19.7183889  79.6864722
# MAHARASHTRA  GADCHIROLI  20.6203889  80.2088889
# MAHARASHTRA  CHANDRAPUR     20.5825  79.6880556
# MAHARASHTRA    KOLHAPUR  16.4310833  74.1414444
#
# [12756 rows x 10 columns]

# %%
home_df.Pincode.nunique()
# Out:
# 1585

# %%
# dropping the duplicates
home_df = home_df.drop_duplicates(subset = ['Pincode'])

# %%
home_df.Latitude = home_df.Latitude.str.replace('-', '', regex = False)
home_df.Longitude = home_df.Longitude.str.replace('-', '', regex = False)
# Out:
# <ipython-input-135-8607ddfe785f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   home_df.Latitude = home_df.Latitude.str.replace('-', '', regex = False)
# <ipython-input-135-8607ddfe785f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   home_df.Longitude = home_df.Longitude.str.replace('-', '', regex = False)

# %%
home_df = home_df.loc[(pd.to_numeric(home_df.Latitude) >= 15.349999) & (pd.to_numeric(home_df.Latitude) <= 22.01999)]
home_df= home_df.loc[(pd.to_numeric(home_df.Longitude) >= 72.34) & (pd.to_numeric(home_df.Longitude) <= 80.55)]

# %%
map_data
# Out:
#                                   State_Name  \
# 0                          Andaman & Nicobar
# 1                                 Chandigarh
# 2   Daman and Diu and Dadra and Nagar Haveli
# 3                                      Delhi
# 4                                    Haryana
# 5                                  Jharkhand
# 6                                  Karnataka
# 7                                     Kerala
# 8                                Lakshadweep
# 9                             Madhya Pradesh
# 10                               Maharashtra
# 11                                    Odisha
# 12                                Puducherry
# 13                                 Tamilnadu
# 14                             Chhattishgarh
# 15                                 Telengana
# 16                            Andhra Pradesh
# 17                                Puducherry
# 18                                       Goa
# 19                          Himachal Pradesh
# 20                                    Punjab
# 21                                 Rajasthan
# 22                                   Gujarat
# 23                               Uttarakhand
# 24                             Uttar Pradesh
# 25                                    Sikkim
# 26                                     Assam
# 27                         Arunachal Pradesh
# 28                                  Nagaland
# 29                                   Manipur
# 30                                   Mizoram
# 31                                   Tripura
# 32                                 Meghalaya
# 33                               West Bengal
# 34                                     Bihar
# 35                                    Ladakh
# 36                         Jammu and Kashmir
#
#                                              geometry
# 0   MULTIPOLYGON (((10341718.474 1449533.161, 1034...
# 1   POLYGON ((8546255.616 3606050.813, 8546315.400...
# 2   MULTIPOLYGON (((8122247.822 2312434.407, 81223...
# 3   POLYGON ((8583390.570 3359116.190, 8583476.212...
# 4   POLYGON ((8524318.539 3516490.865, 8524451.392...
# 5   POLYGON ((9762288.285 2772949.712, 9762301.816...
# 6   MULTIPOLYGON (((8608594.474 2090389.205, 86086...
# 7   POLYGON ((8347733.191 1436381.747, 8347795.745...
# 8   MULTIPOLYGON (((8135256.290 930182.487, 813526...
# 9   POLYGON ((8724343.278 3106498.184, 8724579.382...
# 10  MULTIPOLYGON (((8280974.863 2515416.345, 82809...
# 11  MULTIPOLYGON (((9578537.936 2579790.782, 95786...
# 12  MULTIPOLYGON (((8878474.160 1232399.360, 88784...
# 13  MULTIPOLYGON (((8939353.702 1513831.235, 89395...
# 14  POLYGON ((9275926.808 2765881.317, 9276185.437...
# 15  POLYGON ((8720284.876 2259244.214, 8720421.528...
# 16  POLYGON ((9426056.496 2174632.352, 9426228.484...
# 17  POLYGON ((9150619.186 1888315.624, 9149005.345...
# 18  POLYGON ((8223217.424 1779394.764, 8223279.301...
# 19  POLYGON ((8548682.698 3929291.879, 8548760.706...
# 20  POLYGON ((8442331.679 3830799.529, 8442574.742...
# 21  POLYGON ((8234599.326 3529026.887, 8234599.327...
# 22  POLYGON ((7914780.837 2837315.493, 7915101.603...
# 23  POLYGON ((8801802.136 3692833.282, 8802083.049...
# 24  POLYGON ((8637489.997 3555885.598, 8637654.287...
# 25  POLYGON ((9864726.992 3265074.341, 9865469.610...
# 26  POLYGON ((10380499.251 2872443.723, 10380499.2...
# 27  POLYGON ((10696175.277 3434232.650, 10696981.8...
# 28  POLYGON ((10596805.532 3126858.281, 10597031.2...
# 29  POLYGON ((10527945.945 2960789.340, 10528432.7...
# 30  POLYGON ((10326423.582 2817021.246, 10326465.4...
# 31  POLYGON ((10260260.337 2818339.599, 10260273.8...
# 32  POLYGON ((10222042.433 3013858.327, 10222165.9...
# 33  POLYGON ((9800305.279 3151090.311, 9800377.779...
# 34  POLYGON ((9362949.333 3188807.607, 9362966.106...
# 35  POLYGON ((8550375.654 3927668.327, 8548619.625...
# 36  POLYGON ((8550375.654 3927668.327, 8550332.102...

# %%
map_data.set_index("State_Name", inplace = True)

# %%
home_state_data = map_data.loc[['Maharashtra']]
home_state_data.plot()
# Out:
# <Axes: >

# %%
home_df = home_df.loc['MAHARASHTRA', ['Latitude', 'Longitude']]

# if i want a specific column, we can do like above, but if we want specific rows, we can do\
# df.loc[df.StateName == 'GUJARAT'], extracts only those rows which has state 'GUJARAT'.
home_df = home_df.dropna()

# %%
home_df['Latitude'] = pd.to_numeric(home_df.Latitude)
home_df['Longitude'] = pd.to_numeric(home_df.Longitude)

# %%
home_gdf = gpd.GeoDataFrame(home_df, geometry= gpd.points_from_xy(home_df['Longitude'], home_df['Latitude']))

# %%
home_gdf
# Out:
#               Latitude  Longitude                   geometry
# StateName
# MAHARASHTRA  20.907000  77.602600  POINT (77.60260 20.90700)
# MAHARASHTRA  19.573344  79.442259  POINT (79.44226 19.57334)
# MAHARASHTRA  18.010041  76.071064  POINT (76.07106 18.01004)
# MAHARASHTRA  18.449512  75.675819  POINT (75.67582 18.44951)
# MAHARASHTRA  17.863953  76.478571  POINT (76.47857 17.86395)
# ...                ...        ...                        ...
# MAHARASHTRA  21.003599  75.491717  POINT (75.49172 21.00360)
# MAHARASHTRA  19.988439  73.720725  POINT (73.72073 19.98844)
# MAHARASHTRA  19.988439  73.720725  POINT (73.72073 19.98844)
# MAHARASHTRA  19.861250  79.341778  POINT (79.34178 19.86125)
# MAHARASHTRA  20.117111  79.149417  POINT (79.14942 20.11711)
#
# [1426 rows x 3 columns]

# %%
#ax = home_state_data.plot(figsize=(10,10), color='none', edgecolor='black')
# ax = gdf_pincodes.plot(figsize = (20,20), markersize = 1)
ax= home_gdf.plot(figsize = (10,10), markersize = 10)
#home_state_data.plot(ax=ax, figsize=(10,10), color='none', edgecolor='black')

# %% [markdown]
# **we need to have a matrix X whose shape will be m*2**

# %%
latitude_array = home_df.Latitude.to_numpy()
longitude_array = home_df.Longitude.to_numpy()

# %%
X = np.column_stack((longitude_array, latitude_array))
X
# Out:
# array([[77.6026   , 20.907    ],
#        [79.4422593, 19.5733438],
#        [76.0710641, 18.010041 ],
#        ...,
#        [73.720725 , 19.988439 ],
#        [79.3417778, 19.86125  ],
#        [79.1494167, 20.1171111]])

# %% [markdown]
# **determine K for K -means**

# %%
# let
K = 36
# will also try taking K = 2/K = 4

# %%
# initially..we need to pick k random training examples
randIdx = np.random.permutation(X.shape[0])

# %%
# centroids array dimension are K*2..contains the position for the k centroids
print(randIdx)
centroids = X[randIdx[:K]]
print(centroids)
# Out:
# [1213  827  350 ...   57  629  864]
# [[73.1608889  19.1986389 ]
#  [73.4249095  16.2820094 ]
#  [74.418854   19.524659  ]
#  [72.931896   18.2537853 ]
#  [79.06097222 21.11063889]
#  [75.7262411  17.9671452 ]
#  [73.93122222 18.50330556]
#  [72.8375555  18.9391666 ]
#  [75.7544     19.18145   ]
#  [78.119      20.3850278 ]
#  [75.9623     20.7727    ]
#  [74.512024   20.554431  ]
#  [74.423251   19.833342  ]
#  [72.7954159  19.9716746 ]
#  [73.9751     21.53182   ]
#  [73.0175     19.1100556 ]
#  [73.0464259  19.2103751 ]
#  [77.7523056  20.9298611 ]
#  [73.27669    17.1934    ]
#  [73.9690348  17.0129406 ]
#  [74.547139   17.824379  ]
#  [72.791038   19.6247486 ]
#  [73.99095    17.3651    ]
#  [72.806482   18.910915  ]
#  [73.14418    17.550419  ]
#  [73.4905     20.30019   ]
#  [77.40872    19.202765  ]
#  [74.438      18.3299    ]
#  [75.420925   18.866357  ]
#  [75.6        18.46      ]
#  [75.94216    17.88086   ]
#  [73.44       17.32      ]
#  [79.514389   20.946507  ]
#  [73.1837222  19.2148611 ]
#  [72.8723611  18.6418056 ]
#  [77.4        19.2       ]]

# %%
# let's try to plot and visualize the chosen cluster centroids in the plane
x_coord = centroids[:,0]
y_coord = centroids[:,1]
plt.scatter(X[:,0], X[:,1], c = 'r', marker = 'x', s = 0.1)
plt.scatter(x_coord, y_coord, c = 'b', marker = 'o')
plt.xlabel("xC")
plt.ylabel("yC")
plt.show()

# %%
def find_closest_centroids(X, centroids):
    """
    Computes the centroid memberships for every example

    Args:
        X (ndarray): (m, n) Input values
        centroids (ndarray): k centroids

    Returns:
        idx (array_like): (m,) closest centroids

    """

    # Set K
    K = centroids.shape[0]

    # You need to return the following variables correctly
    idx = np.zeros(X.shape[0], dtype=int)
    no_of_training_examples = X.shape[0]

    for i in range(no_of_training_examples):
        costs = np.zeros(K)
        for j in range (K):
            costs[j] = np.linalg.norm(X[i] - centroids[j])
        idx[i] = np.argmin(costs)

    return idx

# %%
# write a function to find the mean of the new centroid positions
def compute_centroids(X, idx, K):
    """
    Returns the new centroids by computing the means of the
    data points assigned to each centroid.

    Args:
        X (ndarray):   (m, n) Data points
        idx (ndarray): (m,) Array containing index of closest centroid for each
                       example in X. Concretely, idx[i] contains the index of
                       the centroid closest to example i
        K (int):       number of centroids

    Returns:
        centroids (ndarray): (K, n) New centroids computed
    """

    # Useful variables
    m, n = X.shape

    # You need to return the following variables correctly
    centroids = np.zeros((K, n))

    for i in range (K):
        points_assigned = X[idx == i]
        centroids[i] = np.mean(points_assigned, axis=0)

    return centroids

# %%
def run_kMeans(X, initial_centroids, max_iters=10, plot_progress=False):
    """
    Runs the K-Means algorithm on data matrix X, where each row of X
    is a single example
    """

    # Initialize values
    m, n = X.shape
    K = initial_centroids.shape[0]
    centroids = initial_centroids
    previous_centroids = centroids
    idx = np.zeros(m)

    # Run K-Means
    for i in range(max_iters):

        #Output progress
        print("K-Means iteration %d/%d" % (i, max_iters-1))

        # For each example in X, assign it to the closest centroid
        idx = find_closest_centroids(X, centroids)

        # Optionally plot progress
        if plot_progress:
            plot_progress_kMeans(X, centroids, previous_centroids, idx, K, i)
            previous_centroids = centroids

        # Given the memberships, compute new centroids
        centroids = compute_centroids(X, idx, K)
    plt.show()
    return centroids, idx

# %%
def draw_line(p1, p2, style="-k", linewidth=1):
    plt.plot([p1[0], p2[0]], [p1[1], p2[1]], style, linewidth=linewidth)

def plot_data_points(X, idx):
    # plots data points in X, coloring them so that those with the same
    # index assignments in idx have the same color
    plt.scatter(X[:, 0], X[:, 1], c=idx, s = 10)

def plot_progress_kMeans(X, centroids, previous_centroids, idx, K, i):
    # Plot the examples
    plot_data_points(X, idx)

    # Plot the centroids as black 'x's
    plt.scatter(centroids[:, 0], centroids[:, 1], marker='x', c='k', linewidths=3, s = 1-)

    # Plot history of the centroids with lines
    for j in range(centroids.shape[0]):
        draw_line(centroids[j, :], previous_centroids[j, :])

    plt.title("Iteration number %d" %i)
# Out:
#   Cell In[59], line 14
#     plt.scatter(centroids[:, 0], centroids[:, 1], marker='x', c='k', linewidths=3, s = 1-)
#                                                                                          ^
# SyntaxError: invalid syntax

# %%
idx = find_closest_centroids(X,centroids)

# %%
centroids = compute_centroids(X,idx,K)

# %%
print(centroids)
# Out:
# [[73.24280203 19.01767914]
#  [73.64949079 16.1961841 ]
#  [74.52186121 19.35488376]
#  [73.17694503 18.18619171]
#  [78.96542665 21.15270507]
#  [75.49098582 17.85972188]
#  [73.86962591 18.53840701]
#  [72.84267565 19.00698631]
#  [75.82349199 19.4827293 ]
#  [78.34774623 20.23219271]
#  [76.01447212 20.58711191]
#  [74.65499207 20.66856974]
#  [74.44837875 19.90174014]
#  [72.80461057 19.96838486]
#  [74.29817675 21.41016099]
#  [72.96178579 19.08610772]
#  [72.95248337 19.23757424]
#  [77.46751048 20.93958753]
#  [73.37311681 17.05282833]
#  [74.37419202 16.86562684]
#  [74.70284466 17.62735314]
#  [72.81368436 19.56740839]
#  [74.06605828 17.49954049]
#  [72.593241   18.8704575 ]
#  [73.29901681 17.71499639]
#  [73.71656866 20.04105522]
#  [77.57224046 19.67015881]
#  [74.44648666 18.47294735]
#  [75.30531305 18.90709558]
#  [75.57384637 18.41653954]
#  [76.19941483 17.89672034]
#  [73.53165786 17.47581296]
#  [79.74714438 20.55810208]
#  [73.36777009 19.28760987]
#  [73.10338247 18.58948707]
#  [77.28371261 19.07693401]]

# %%
# Set initial centroids
K = 36

# Number of iterations
max_iters = 20

centroids, idx = run_kMeans(X, centroids, max_iters, plot_progress=True)
# Out:
# K-Means iteration 0/19
# K-Means iteration 1/19
# K-Means iteration 2/19
# K-Means iteration 3/19
# K-Means iteration 4/19
# K-Means iteration 5/19
# K-Means iteration 6/19
# K-Means iteration 7/19
# K-Means iteration 8/19
# K-Means iteration 9/19
# K-Means iteration 10/19
# K-Means iteration 11/19
# K-Means iteration 12/19
# K-Means iteration 13/19
# K-Means iteration 14/19
# K-Means iteration 15/19
# K-Means iteration 16/19
# K-Means iteration 17/19
# K-Means iteration 18/19
# K-Means iteration 19/19

# %%
# let's try to plot and visualize the chosen cluster centroids in the plane
x_coord = centroids[:,0]
y_coord = centroids[:,1]
plt.scatter(X[:,0], X[:,1], c = 'r', marker = 'x', s = 0.1)
plt.scatter(x_coord, y_coord, c = 'b', marker = 'o')
plt.xlabel("xC")
plt.ylabel("yC")
plt.show()
